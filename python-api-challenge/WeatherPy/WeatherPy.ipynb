# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
weather_api_key = "1985c73f76f7aa256c12b73d4b19d71f"
appid = weather_api_key
settings = {"units": "imperial", "appid": weather_api_key}
url = f"{url}appid={weather_api_key}&units={units}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]        
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mili
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | kirov
# Processing Record 5 of Set 1 | alvorada
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | ylitornio
# Processing Record 9 of Set 1 | kikvidze
# Processing Record 10 of Set 1 | puerto natales
# Processing Record 11 of Set 1 | west island
# Processing Record 12 of Set 1 | kavieng
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | utrik
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | sao vicente
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | biryusinsk
# Processing Record 22 of Set 1 | palmer
# Processing Record 23 of Set 1 | hadibu
# Processing Record 24 of Set 1 | ballito
# Processing Record 25 of Set 1 | xining
# Processing Record 26 of Set 1 | soio
# Processing Record 27 of Set 1 | wailua homesteads
# Processing Record 28 of Set 1 | luderitz
# Processing Record 29 of Set 1 | hengchun
# Processing Record 30 of Set 1 | acajutla
# Processing Record 31 of Set 1 | invercargill
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | port mathurin
# Processing Record 35 of Set 1 | galliano
# Processing Record 36 of Set 1 | kalymnos
# Processing Record 37 of Set 1 | boquira
# Processing Record 38 of Set 1 | st. john's
# Processing Record 39 of Set 1 | constantia
# Processing Record 40 of Set 1 | vorgashor
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | akureyri
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | afaahiti
# Processing Record 46 of Set 1 | lhasa
# Processing Record 47 of Set 1 | nova sintra
# Processing Record 48 of Set 1 | grytviken
# Processing Record 49 of Set 1 | anadyr
# Processing Record 50 of Set 1 | tiksi
# Processing Record 0 of Set 2 | saipan
# Processing Record 1 of Set 2 | elmali
# Processing Record 2 of Set 2 | rongelap
# Processing Record 3 of Set 2 | stanley
# Processing Record 4 of Set 2 | vanimo
# Processing Record 5 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 2 | udachny
# Processing Record 7 of Set 2 | san luis de la loma
# Processing Record 8 of Set 2 | sarandi del yi
# Processing Record 9 of Set 2 | mukah
# City not found. Skipping...
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | plainview
# Processing Record 13 of Set 2 | papatowai
# Processing Record 14 of Set 2 | lewistown
# Processing Record 15 of Set 2 | susuman
# Processing Record 16 of Set 2 | laguna de perlas
# Processing Record 17 of Set 2 | laojunmiao
# Processing Record 18 of Set 2 | walvis bay
# Processing Record 19 of Set 2 | mil'kovo
# Processing Record 20 of Set 2 | castillos
# Processing Record 21 of Set 2 | aasiaat
# Processing Record 22 of Set 2 | fort bragg
# Processing Record 23 of Set 2 | sur
# Processing Record 24 of Set 2 | alta
# Processing Record 25 of Set 2 | kapit
# Processing Record 26 of Set 2 | susa
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | port saint john's
# Processing Record 30 of Set 2 | santa elena de uairen
# Processing Record 31 of Set 2 | kalmunai
# Processing Record 32 of Set 2 | iskateley
# Processing Record 33 of Set 2 | klyuchi
# Processing Record 34 of Set 2 | turinsk
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | yung shue wan
# Processing Record 38 of Set 2 | whitehorse
# Processing Record 39 of Set 2 | qaqortoq
# Processing Record 40 of Set 2 | san patricio
# Processing Record 41 of Set 2 | ryotsu-minato
# Processing Record 42 of Set 2 | puerto ayacucho
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | olonkinbyen
# Processing Record 45 of Set 2 | tolanaro
# Processing Record 46 of Set 2 | santa vitoria
# Processing Record 47 of Set 2 | batangafo
# Processing Record 48 of Set 2 | inari
# Processing Record 49 of Set 2 | jinghong
# Processing Record 0 of Set 3 | roma
# Processing Record 1 of Set 3 | aracruz
# Processing Record 2 of Set 3 | caleta de carquin
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | ghanzi
# Processing Record 5 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | mariehamn
# Processing Record 8 of Set 3 | afif
# Processing Record 9 of Set 3 | urengoy
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | salinopolis
# Processing Record 12 of Set 3 | lospalos
# Processing Record 13 of Set 3 | charlotte
# Processing Record 14 of Set 3 | margaret river
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 3 | dean funes
# Processing Record 18 of Set 3 | limanowa
# Processing Record 19 of Set 3 | hirara
# Processing Record 20 of Set 3 | lamar
# Processing Record 21 of Set 3 | guiuan
# Processing Record 22 of Set 3 | maintirano
# Processing Record 23 of Set 3 | zhangye
# Processing Record 24 of Set 3 | yeppoon
# Processing Record 25 of Set 3 | sorong
# Processing Record 26 of Set 3 | nurota
# Processing Record 27 of Set 3 | kone
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | smarde
# City not found. Skipping...
# Processing Record 30 of Set 3 | okhotsk
# Processing Record 31 of Set 3 | pasuquin
# Processing Record 32 of Set 3 | alegrete
# Processing Record 33 of Set 3 | bikenibeu village
# Processing Record 34 of Set 3 | petropavl
# Processing Record 35 of Set 3 | brisas de zicatela
# Processing Record 36 of Set 3 | samarinda
# Processing Record 37 of Set 3 | santiago de cao
# Processing Record 38 of Set 3 | kogalym
# Processing Record 39 of Set 3 | hawaiian paradise park
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | bamboo flat
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | langepas
# Processing Record 44 of Set 3 | bestobe
# Processing Record 45 of Set 3 | nelson bay
# Processing Record 46 of Set 3 | ivins
# Processing Record 47 of Set 3 | prokop'yevsk
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | mount pearl
# Processing Record 0 of Set 4 | tomatlan
# Processing Record 1 of Set 4 | flying fish cove
# Processing Record 2 of Set 4 | chonchi
# Processing Record 3 of Set 4 | kwang binh
# Processing Record 4 of Set 4 | sabang
# Processing Record 5 of Set 4 | sechura
# Processing Record 6 of Set 4 | asadabad
# Processing Record 7 of Set 4 | villa huidobro
# Processing Record 8 of Set 4 | tazovsky
# Processing Record 9 of Set 4 | al hazm
# Processing Record 10 of Set 4 | peace river
# Processing Record 11 of Set 4 | santa cruz
# Processing Record 12 of Set 4 | al-`ula
# City not found. Skipping...
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | mbabane
# Processing Record 16 of Set 4 | dom pedrito
# Processing Record 17 of Set 4 | corner brook
# Processing Record 18 of Set 4 | changli
# Processing Record 19 of Set 4 | isafjordur
# Processing Record 20 of Set 4 | greymouth
# Processing Record 21 of Set 4 | katsuren-haebaru
# Processing Record 22 of Set 4 | cabedelo
# Processing Record 23 of Set 4 | anna regina
# Processing Record 24 of Set 4 | dawson creek
# Processing Record 25 of Set 4 | keflavik
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | richards bay
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | leiston
# Processing Record 30 of Set 4 | wad medani
# Processing Record 31 of Set 4 | prince george
# Processing Record 32 of Set 4 | jutai
# Processing Record 33 of Set 4 | hinthada
# Processing Record 34 of Set 4 | south windsor
# Processing Record 35 of Set 4 | kailua-kona
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 38 of Set 4 | farsan
# Processing Record 39 of Set 4 | guatire
# Processing Record 40 of Set 4 | dudinka
# Processing Record 41 of Set 4 | atafu village
# Processing Record 42 of Set 4 | kodinsk
# Processing Record 43 of Set 4 | beipiao
# Processing Record 44 of Set 4 | timimoun
# Processing Record 45 of Set 4 | alesund
# Processing Record 46 of Set 4 | kurmuk
# Processing Record 47 of Set 4 | newman
# Processing Record 48 of Set 4 | yuzhno-kurilsk
# Processing Record 49 of Set 4 | palikir - national government center
# Processing Record 0 of Set 5 | matale
# Processing Record 1 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 5 | maumere
# Processing Record 3 of Set 5 | sisimiut
# Processing Record 4 of Set 5 | baicheng
# Processing Record 5 of Set 5 | alofi
# Processing Record 6 of Set 5 | kugesi
# Processing Record 7 of Set 5 | tocopilla
# Processing Record 8 of Set 5 | usinsk
# Processing Record 9 of Set 5 | ta`u
# Processing Record 10 of Set 5 | new norfolk
# Processing Record 11 of Set 5 | bet shemesh
# Processing Record 12 of Set 5 | mournies
# Processing Record 13 of Set 5 | taitung city
# Processing Record 14 of Set 5 | nizhneudinsk
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | pemangkat
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | kiruna
# Processing Record 20 of Set 5 | ebon
# Processing Record 21 of Set 5 | shubarkuduk
# Processing Record 22 of Set 5 | mahibadhoo
# Processing Record 23 of Set 5 | valley city
# Processing Record 24 of Set 5 | itaituba
# Processing Record 25 of Set 5 | filadelfia
# Processing Record 26 of Set 5 | angaur state
# Processing Record 27 of Set 5 | ramhormoz
# Processing Record 28 of Set 5 | conde
# Processing Record 29 of Set 5 | hermanus
# Processing Record 30 of Set 5 | ad darb
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | velikiye luki
# Processing Record 33 of Set 5 | mtambile
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | kerikeri
# Processing Record 36 of Set 5 | tucuma
# Processing Record 37 of Set 5 | salta
# Processing Record 38 of Set 5 | punta arenas
# Processing Record 39 of Set 5 | ambon
# Processing Record 40 of Set 5 | port lincoln
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | balabac
# Processing Record 43 of Set 5 | el idrissia
# Processing Record 44 of Set 5 | egilsstadir
# Processing Record 45 of Set 5 | hilo
# Processing Record 46 of Set 5 | myrina
# Processing Record 47 of Set 5 | igarka
# Processing Record 48 of Set 5 | inirida
# Processing Record 49 of Set 5 | ancud
# Processing Record 0 of Set 6 | georgetown
# Processing Record 1 of Set 6 | majie
# Processing Record 2 of Set 6 | naryn
# Processing Record 3 of Set 6 | chilecito
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | copiapo
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | cockburn town
# Processing Record 8 of Set 6 | karatas
# Processing Record 9 of Set 6 | charters towers
# Processing Record 10 of Set 6 | navirai
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | vorkuta
# Processing Record 13 of Set 6 | horta
# Processing Record 14 of Set 6 | guixi
# Processing Record 15 of Set 6 | januaria
# Processing Record 16 of Set 6 | tofol
# Processing Record 17 of Set 6 | camana
# Processing Record 18 of Set 6 | belokurikha
# Processing Record 19 of Set 6 | ridder
# Processing Record 20 of Set 6 | flin flon
# Processing Record 21 of Set 6 | la passe
# Processing Record 22 of Set 6 | merikanjaka
# City not found. Skipping...
# Processing Record 23 of Set 6 | cavalaire-sur-mer
# Processing Record 24 of Set 6 | badger
# Processing Record 25 of Set 6 | malvan
# Processing Record 26 of Set 6 | fort st. john
# Processing Record 27 of Set 6 | at taraf
# Processing Record 28 of Set 6 | uturoa
# Processing Record 29 of Set 6 | puruaran
# Processing Record 30 of Set 6 | villa dolores
# Processing Record 31 of Set 6 | vadso
# Processing Record 32 of Set 6 | herzliya pituah
# City not found. Skipping...
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | tambura
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 6 | bosaso
# Processing Record 38 of Set 6 | belo sur tsiribihina
# Processing Record 39 of Set 6 | dambulla
# Processing Record 40 of Set 6 | badagara
# Processing Record 41 of Set 6 | vangaindrano
# Processing Record 42 of Set 6 | otacilio costa
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | puerto madero
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | tralee
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | port-vila
# Processing Record 0 of Set 7 | irece
# Processing Record 1 of Set 7 | joshimath
# Processing Record 2 of Set 7 | rio de janeiro
# Processing Record 3 of Set 7 | cudillero
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | pontes e lacerda
# Processing Record 6 of Set 7 | conception bay south
# Processing Record 7 of Set 7 | kapuskasing
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | vilyuchinsk
# Processing Record 10 of Set 7 | byron bay
# Processing Record 11 of Set 7 | manokwari
# Processing Record 12 of Set 7 | wynyard
# Processing Record 13 of Set 7 | colonia
# Processing Record 14 of Set 7 | adrar
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | enewetak
# Processing Record 17 of Set 7 | at-bashi
# Processing Record 18 of Set 7 | tura
# Processing Record 19 of Set 7 | mount isa
# Processing Record 20 of Set 7 | sao sepe
# Processing Record 21 of Set 7 | kibuye
# Processing Record 22 of Set 7 | pandan
# Processing Record 23 of Set 7 | emerald
# Processing Record 24 of Set 7 | khandyga
# Processing Record 25 of Set 7 | cedeira
# Processing Record 26 of Set 7 | tambopata
# Processing Record 27 of Set 7 | broome
# Processing Record 28 of Set 7 | salalah
# Processing Record 29 of Set 7 | tadine
# Processing Record 30 of Set 7 | anahuac
# Processing Record 31 of Set 7 | sayat
# Processing Record 32 of Set 7 | nar'yan-mar
# Processing Record 33 of Set 7 | ghadamis
# Processing Record 34 of Set 7 | remire-montjoly
# Processing Record 35 of Set 7 | nouadhibou
# Processing Record 36 of Set 7 | leticia
# Processing Record 37 of Set 7 | huatabampo
# Processing Record 38 of Set 7 | mont-dore
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | khor
# Processing Record 41 of Set 7 | cuatro cienegas de carranza
# Processing Record 42 of Set 7 | kirakira
# Processing Record 43 of Set 7 | englewood
# Processing Record 44 of Set 7 | maigo
# Processing Record 45 of Set 7 | klaksvik
# Processing Record 46 of Set 7 | keelung
# Processing Record 47 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 7 | fabens
# Processing Record 49 of Set 7 | haiku-pauwela
# Processing Record 0 of Set 8 | puerto baquerizo moreno
# Processing Record 1 of Set 8 | sosnovo-ozerskoye
# Processing Record 2 of Set 8 | eyl
# Processing Record 3 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 8 | pacific
# Processing Record 5 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 6 of Set 8 | sao borja
# Processing Record 7 of Set 8 | zyryanovsk
# Processing Record 8 of Set 8 | gracemere
# Processing Record 9 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 10 of Set 8 | greenville
# Processing Record 11 of Set 8 | howrah
# Processing Record 12 of Set 8 | erenhot
# Processing Record 13 of Set 8 | berezovyy
# Processing Record 14 of Set 8 | ambodifotatra
# Processing Record 15 of Set 8 | tangalle
# Processing Record 16 of Set 8 | bargaal
# Processing Record 17 of Set 8 | sangamner
# Processing Record 18 of Set 8 | skeldon
# Processing Record 19 of Set 8 | trairi
# Processing Record 20 of Set 8 | santa ana
# Processing Record 21 of Set 8 | swift current
# Processing Record 22 of Set 8 | bismarck
# Processing Record 23 of Set 8 | caiaponia
# Processing Record 24 of Set 8 | la plata
# Processing Record 25 of Set 8 | kayangel
# Processing Record 26 of Set 8 | grand-bassam
# Processing Record 27 of Set 8 | tsiombe
# Processing Record 28 of Set 8 | ayapel
# Processing Record 29 of Set 8 | kimbe
# Processing Record 30 of Set 8 | christchurch
# Processing Record 31 of Set 8 | puerto real
# Processing Record 32 of Set 8 | arkhangel'sk
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | toba
# Processing Record 35 of Set 8 | pisco
# Processing Record 36 of Set 8 | san antonio
# Processing Record 37 of Set 8 | merizo village
# Processing Record 38 of Set 8 | piritiba
# Processing Record 39 of Set 8 | cochin
# Processing Record 40 of Set 8 | kingston
# Processing Record 41 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 42 of Set 8 | montalvo
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | nyrob
# Processing Record 45 of Set 8 | cabugao
# Processing Record 46 of Set 8 | cooper's town
# Processing Record 47 of Set 8 | fale old settlement
# Processing Record 48 of Set 8 | esil
# Processing Record 49 of Set 8 | north kingstown
# Processing Record 0 of Set 9 | sulak
# Processing Record 1 of Set 9 | pacific grove
# Processing Record 2 of Set 9 | antananarivo
# Processing Record 3 of Set 9 | salem
# Processing Record 4 of Set 9 | bandar
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | vigan
# Processing Record 7 of Set 9 | general acha
# Processing Record 8 of Set 9 | yeniseysk
# Processing Record 9 of Set 9 | siguiri
# Processing Record 10 of Set 9 | bakhmach
# Processing Record 11 of Set 9 | saint-pierre
# Processing Record 12 of Set 9 | toamasina
# Processing Record 13 of Set 9 | palapye
# Processing Record 14 of Set 9 | porto novo
# Processing Record 15 of Set 9 | grand falls-windsor
# Processing Record 16 of Set 9 | penzance
# Processing Record 17 of Set 9 | gadzhiyevo
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | suances
# Processing Record 20 of Set 9 | cascais
# Processing Record 21 of Set 9 | kabompo
# Processing Record 22 of Set 9 | kem'
# Processing Record 23 of Set 9 | wotho
# Processing Record 24 of Set 9 | kilindoni
# Processing Record 25 of Set 9 | vilhena
# Processing Record 26 of Set 9 | jawf al maqbabah
# Processing Record 27 of Set 9 | mantyharju
# Processing Record 28 of Set 9 | nizhniy kuranakh
# Processing Record 29 of Set 9 | carencro
# Processing Record 30 of Set 9 | igrim
# Processing Record 31 of Set 9 | askoy
# Processing Record 32 of Set 9 | kuala terengganu
# Processing Record 33 of Set 9 | ierapetra
# Processing Record 34 of Set 9 | james island
# City not found. Skipping...
# Processing Record 35 of Set 9 | arnprior
# Processing Record 36 of Set 9 | banikoara
# Processing Record 37 of Set 9 | east ballina
# Processing Record 38 of Set 9 | cobija
# Processing Record 39 of Set 9 | rio cuarto
# Processing Record 40 of Set 9 | puerto deseado
# Processing Record 41 of Set 9 | aconibe
# Processing Record 42 of Set 9 | altamont
# Processing Record 43 of Set 9 | aykhal
# Processing Record 44 of Set 9 | hawera
# Processing Record 45 of Set 9 | crane
# Processing Record 46 of Set 9 | upington
# Processing Record 47 of Set 9 | ust-nera
# Processing Record 48 of Set 9 | taoyuan city
# Processing Record 49 of Set 9 | egersund
# Processing Record 0 of Set 10 | suomussalmi
# Processing Record 1 of Set 10 | lamu
# Processing Record 2 of Set 10 | udgir
# Processing Record 3 of Set 10 | ouadda
# Processing Record 4 of Set 10 | diourbel
# Processing Record 5 of Set 10 | sokoto
# Processing Record 6 of Set 10 | orchard homes
# Processing Record 7 of Set 10 | mantua
# Processing Record 8 of Set 10 | minas de marcona
# Processing Record 9 of Set 10 | taixing
# Processing Record 10 of Set 10 | revda
# Processing Record 11 of Set 10 | kyakhta
# Processing Record 12 of Set 10 | mont-laurier
# Processing Record 13 of Set 10 | touros
# Processing Record 14 of Set 10 | al ghayzah
# Processing Record 15 of Set 10 | ii
# City not found. Skipping...
# Processing Record 16 of Set 10 | urucara
# Processing Record 17 of Set 10 | waingapu
# Processing Record 18 of Set 10 | ordos
# City not found. Skipping...
# Processing Record 19 of Set 10 | antsiranana
# Processing Record 20 of Set 10 | labasa
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | glace bay
# Processing Record 23 of Set 10 | berdigestyakh
# Processing Record 24 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 25 of Set 10 | ciudad lazaro cardenas
# Processing Record 26 of Set 10 | weyburn
# Processing Record 27 of Set 10 | kissidougou
# Processing Record 28 of Set 10 | patacamaya
# Processing Record 29 of Set 10 | gebeit
# Processing Record 30 of Set 10 | north bend
# Processing Record 31 of Set 10 | ngardmau
# Processing Record 32 of Set 10 | kastsyukovichy
# Processing Record 33 of Set 10 | krasnovishersk
# Processing Record 34 of Set 10 | pariaman
# Processing Record 35 of Set 10 | haimen
# Processing Record 36 of Set 10 | boguchany
# Processing Record 37 of Set 10 | fredonia
# Processing Record 38 of Set 10 | el calafate
# Processing Record 39 of Set 10 | pasni
# Processing Record 40 of Set 10 | lazaro cardenas
# Processing Record 41 of Set 10 | sydney
# Processing Record 42 of Set 10 | kostanay
# Processing Record 43 of Set 10 | healesville
# Processing Record 44 of Set 10 | dharamsala
# Processing Record 45 of Set 10 | alice springs
# Processing Record 46 of Set 10 | thaba-tseka
# Processing Record 47 of Set 10 | papao
# Processing Record 48 of Set 10 | luwingu
# Processing Record 49 of Set 10 | ryl'sk
# Processing Record 0 of Set 11 | praia da vitoria
# Processing Record 1 of Set 11 | ust-tsilma
# Processing Record 2 of Set 11 | yaren
# Processing Record 3 of Set 11 | boa vista
# Processing Record 4 of Set 11 | obock
# Processing Record 5 of Set 11 | axim
# Processing Record 6 of Set 11 | zychlin
# Processing Record 7 of Set 11 | oudtshoorn
# Processing Record 8 of Set 11 | jiangyou
# Processing Record 9 of Set 11 | port isabel
# Processing Record 10 of Set 11 | finale ligure
# Processing Record 11 of Set 11 | mirny
# Processing Record 12 of Set 11 | kristiansund
# Processing Record 13 of Set 11 | la cruz
# Processing Record 14 of Set 11 | necochea
# Processing Record 15 of Set 11 | dickinson
# Processing Record 16 of Set 11 | qacha's nek
# Processing Record 17 of Set 11 | silvania
# Processing Record 18 of Set 11 | sarakhs
# Processing Record 19 of Set 11 | sitampiky
# City not found. Skipping...
# Processing Record 20 of Set 11 | kourou
# Processing Record 21 of Set 11 | island harbour
# Processing Record 22 of Set 11 | shahpur
# Processing Record 23 of Set 11 | haukipudas
# Processing Record 24 of Set 11 | ceylanpinar
# Processing Record 25 of Set 11 | sittwe
# Processing Record 26 of Set 11 | saint-philippe
# Processing Record 27 of Set 11 | kupang
# Processing Record 28 of Set 11 | raikot
# Processing Record 29 of Set 11 | zell am see
# Processing Record 30 of Set 11 | myslakowice
# Processing Record 31 of Set 11 | lihue
# Processing Record 32 of Set 11 | serro
# Processing Record 33 of Set 11 | paidha
# Processing Record 34 of Set 11 | guaruja
# Processing Record 35 of Set 11 | bazarak
# Processing Record 36 of Set 11 | simanggang
# Processing Record 37 of Set 11 | basco
# Processing Record 38 of Set 11 | kunshan
# Processing Record 39 of Set 11 | woolgoolga
# Processing Record 40 of Set 11 | puerto aysen
# Processing Record 41 of Set 11 | contamana
# Processing Record 42 of Set 11 | brookings
# Processing Record 43 of Set 11 | kudahuvadhoo
# Processing Record 44 of Set 11 | batroun
# Processing Record 45 of Set 11 | san blas
# Processing Record 46 of Set 11 | fort mcmurray
# Processing Record 47 of Set 11 | sarkhej
# Processing Record 48 of Set 11 | hauterive
# Processing Record 49 of Set 11 | chiredzi
# Processing Record 0 of Set 12 | ciudad bolivar
# Processing Record 1 of Set 12 | carauari
# Processing Record 2 of Set 12 | jinchang
# Processing Record 3 of Set 12 | vallenar
# Processing Record 4 of Set 12 | cuenca
# Processing Record 5 of Set 12 | al jahra'
# Processing Record 6 of Set 12 | vanino
# Processing Record 7 of Set 12 | medicine hat
# Processing Record 8 of Set 12 | kongolo
# Processing Record 9 of Set 12 | imbituba
# Processing Record 10 of Set 12 | yvetot
# Processing Record 11 of Set 12 | tarrafal
# Processing Record 12 of Set 12 | quetigny
# Processing Record 13 of Set 12 | quellon
# Processing Record 14 of Set 12 | ibotirama
# Processing Record 15 of Set 12 | saint-joseph
# Processing Record 16 of Set 12 | fort scott
# Processing Record 17 of Set 12 | vila franca do campo
# Processing Record 18 of Set 12 | puerto armuelles
# Processing Record 19 of Set 12 | hastings
# Processing Record 20 of Set 12 | cill airne
# Processing Record 21 of Set 12 | murghob
# Processing Record 22 of Set 12 | gobabis
# Processing Record 23 of Set 12 | uliastay
# Processing Record 24 of Set 12 | keetmanshoop
# Processing Record 25 of Set 12 | robertsport
# Processing Record 26 of Set 12 | laikit, laikit ii (dimembe)
# Processing Record 27 of Set 12 | arar
# Processing Record 28 of Set 12 | chibougamau
# Processing Record 29 of Set 12 | novodvinsk
# Processing Record 30 of Set 12 | goz beida
# Processing Record 31 of Set 12 | ribadesella
# Processing Record 32 of Set 12 | tual
# Processing Record 33 of Set 12 | saquarema
# Processing Record 34 of Set 12 | severo-yeniseyskiy
# Processing Record 35 of Set 12 | miles city
# Processing Record 36 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 37 of Set 12 | la libertad
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count
# Out:
# <bound method DataFrame.count of                             City      Lat       Lng  Max Temp  Humidity  \
# 0                           mili   6.0815  171.7350     81.79        77
# 1                         albany  42.6001  -73.9662     40.80        52
# 2    edinburgh of the seven seas -37.0676  -12.3116     60.85        76
# 3                          kirov  58.5966   49.6601     10.58        95
# 4                       alvorada -12.4800  -49.1247     78.48        84
# ..                           ...      ...       ...       ...       ...
# 561                         tual  -5.6667  132.7500     83.97        76
# 562                    saquarema -22.9200  -42.5103     82.44        88
# 563           severo-yeniseyskiy  60.3725   93.0408     -0.27        98
# 564                   miles city  46.4083 -105.8406     43.77        75
# 565                  la libertad  -2.2333  -80.9000     87.46        66
#
#      Cloudiness  Wind Speed Country        Date
# 0            99       18.14      MH  1707079696
# 1             1        1.99      US  1707079016
# 2            70       18.79      SH  1707079696
# 3           100       10.00      RU  1707079697
# 4           100        2.77      BR  1707079697
# ..          ...         ...     ...         ...
# 561         100       12.46      ID  1707079795
# 562         100       10.94      BR  1707079795
# 563         100        3.94      RU  1707079796
# 564         100        5.75      US  1707079796
# 565          75       13.80      EC  1707079796
#
# [566 rows x 9 columns]>

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                         mili   6.0815  171.7350     81.79        77
# 1                       albany  42.6001  -73.9662     40.80        52
# 2  edinburgh of the seven seas -37.0676  -12.3116     60.85        76
# 3                        kirov  58.5966   49.6601     10.58        95
# 4                     alvorada -12.4800  -49.1247     78.48        84
#
#    Cloudiness  Wind Speed Country        Date
# 0          99       18.14      MH  1707079696
# 1           1        1.99      US  1707079016
# 2          70       18.79      SH  1707079696
# 3         100       10.00      RU  1707079697
# 4         100        2.77      BR  1707079697

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                               mili   6.0815  171.7350     81.79        77
# 1                             albany  42.6001  -73.9662     40.80        52
# 2        edinburgh of the seven seas -37.0676  -12.3116     60.85        76
# 3                              kirov  58.5966   49.6601     10.58        95
# 4                           alvorada -12.4800  -49.1247     78.48        84
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99       18.14      MH  1707079696
# 1                 1        1.99      US  1707079016
# 2                70       18.79      SH  1707079696
# 3               100       10.00      RU  1707079697
# 4               100        2.77      BR  1707079697

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], 
            city_data_df["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             mili   6.0815  171.7350     81.79        77          99
# 1           albany  42.6001  -73.9662     40.80        52           1
# 3            kirov  58.5966   49.6601     10.58        95         100
# 6          iqaluit  63.7506  -68.5145     -4.27        77         100
# 7        ylitornio  66.3089   23.6773     17.56        95          99
#
#          Wind Speed Country        Date
# City_ID
# 0             18.14      MH  1707079696
# 1              1.99      US  1707079016
# 3             10.00      RU  1707079697
# 6              8.05      CA  1707079697
# 7              6.51      FI  1707079697

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2        edinburgh of the seven seas -37.0676  -12.3116     60.85        76
# 4                           alvorada -12.4800  -49.1247     78.48        84
# 5                           waitangi -43.9535 -176.5597     65.82        83
# 9                     puerto natales -51.7236  -72.4875     73.85        35
# 10                       west island -12.1568   96.8225     82.38        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                70       18.79      SH  1707079696
# 4               100        2.77      BR  1707079697
# 5                35        1.99      NZ  1707079697
# 9                75       32.21      CL  1707079698
# 10              100        9.22      CC  1707079698

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.8704463027451437

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.49336811113442347

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.37426642632876334

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.26604424242981334

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.24155681276475308

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.3175228671663468

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: -0.037271716116458166

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.15386851630058468

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
